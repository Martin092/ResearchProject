# %%
from src.utility.SettingsSimulator import SettingsSimulator
import matplotlib
# %matplotlib inline

# %%
settings_dir = "../../../configurations/poster_plots"

# %%
simulator = SettingsSimulator(settings_dir, "random.json")
simulator.simulate_all()
# Out:
# ...
# Running Random FS-SCB M=15 80 features: 100%|██████████| 5/5 [03:02<00:00, 36.59s/it]

# %%
simulator = SettingsSimulator(settings_dir, "informed.json")
simulator.simulate_all()
# Out:
# ...
# Running Bayesian FS-SCB M=15, 80 features: 100%|██████████| 5/5 [02:51<00:00, 34.30s/it]
