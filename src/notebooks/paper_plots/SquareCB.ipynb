# %%
from src.utility.SettingsSimulator import SettingsSimulator
import matplotlib
# %matplotlib inline

# %%
settings_dir = "../../../configurations/paper_figures"

# %%
simulator = SettingsSimulator(settings_dir, "SquareCB_different_k.json")
simulator.simulate_all()
# Out:
# ...
# Running k=60: 100%|██████████| 10/10 [00:36<00:00,  3.62s/it]

# %%
simulator = SettingsSimulator(settings_dir, "SquareCB_different_s.json")
simulator.simulate_all()
# Out:
# ...
# Running s=40: 100%|██████████| 10/10 [00:39<00:00,  3.99s/it]

# %%
simulator = SettingsSimulator(settings_dir, "SquareCB_diff_k_bayesian.json")
simulator.simulate_all()
# Out:
# ...
# Running k=20: 100%|██████████| 10/10 [01:05<00:00,  6.57s/it]

# %%
simulator = SettingsSimulator(settings_dir, "squareCB_bayesian_full_x.json")
simulator.simulate_all()
# Out:
# ...
# Running SquareCB - Bayesian with full X: 100%|██████████| 10/10 [01:27<00:00,  8.73s/it]
