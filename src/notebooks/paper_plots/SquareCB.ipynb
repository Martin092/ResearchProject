# %%
from src.utility.SettingsSimulator import SettingsSimulator

# %%
settings_dir = "../../../configurations/paper_figures"
simulator = SettingsSimulator(settings_dir, "SquareCB_features.json")

simulator.simulate_all("Number of features comparison")
# Out:
# Running k=100: 100%|██████████| 10/10 [00:37<00:00,  3.74s/it]
# Running k=90:   0%|          | 0/10 [00:00<?, ?it/s]/home/martin/Projects/SparseSequentialLearning/.venv/lib/python3.11/site-packages/cvxpy/problems/problem.py:1504: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# Running k=90: 100%|██████████| 10/10 [00:38<00:00,  3.83s/it]
# Running k=80: 100%|██████████| 10/10 [00:35<00:00,  3.57s/it]
# Running k=70: 100%|██████████| 10/10 [00:35<00:00,  3.55s/it]
# Running k=60: 100%|██████████| 10/10 [00:35<00:00,  3.56s/it]

# %%
settings_dir = "../../../configurations/paper_figures"
simulator = SettingsSimulator(settings_dir, "SquareCB_comparison.json")

simulator.simulate_all("SquareCB against LinUCB")
# Out:
# Running SquareCB k=90:   0%|          | 0/10 [00:00<?, ?it/s]
