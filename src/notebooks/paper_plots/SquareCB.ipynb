# %%
from src.utility.SettingsSimulator import SettingsSimulator

# %%
settings_dir = "../../../configurations/paper_figures"
simulator = SettingsSimulator(settings_dir, "SquareCB_features.json")
simulator.simulate_all("Number of features comparison")
# Out:
# Running k=100: 100%|██████████| 10/10 [00:39<00:00,  3.95s/it]
# Running k=90: 100%|██████████| 10/10 [00:40<00:00,  4.05s/it]
# Running k=80: 100%|██████████| 10/10 [05:14<00:00, 31.50s/it]
# Running k=70: 100%|██████████| 10/10 [00:36<00:00,  3.63s/it]
# Running k=60: 100%|██████████| 10/10 [00:34<00:00,  3.48s/it]

# %%
settings_dir = "../../../configurations/paper_figures"
simulator = SettingsSimulator(settings_dir, "SquareCB_comparison.json")
simulator.simulate_all("SquareCB against LinUCB")
# Out:
# Running SquareCB k=80:  20%|██        | 2/10 [00:06<00:27,  3.45s/it]/home/martin/Projects/SparseSequentialLearning/.venv/lib/python3.11/site-packages/cvxpy/problems/problem.py:1504: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# Running SquareCB k=80: 100%|██████████| 10/10 [00:33<00:00,  3.36s/it]
# Running LinUCB with full features: 100%|██████████| 10/10 [00:27<00:00,  2.73s/it]
# Running LinUCB with k=80: 100%|██████████| 10/10 [00:56<00:00,  5.64s/it]

# %%
settings_dir = "../../../configurations/paper_figures"
simulator = SettingsSimulator(settings_dir, "SquareCB_features.json")
simulator.simulate_all("Number of features comparison")
