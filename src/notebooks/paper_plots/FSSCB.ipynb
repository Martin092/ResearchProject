# %%
from src.utility.SettingsSimulator import SettingsSimulator

# %%
settings_dir = "../../../configurations/paper_figures"
simulator = SettingsSimulator(settings_dir, "FSSCB_different_k_bayesian.json")
simulator.simulate_all("Number of features comparison")
# Out:
# ...
# Running FS-SCB Anova 100 feats:   0%|          | 0/5 [00:00<?, ?it/s]/home/martin/Projects/SparseSequentialLearning/.venv/lib/python3.11/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=105 is greater than n_features=100. All the features will be returned.
#   warnings.warn(
# Running FS-SCB Anova 100 feats:  20%|██        | 1/5 [00:21<01:27, 21.83s/it]/home/martin/Projects/SparseSequentialLearning/.venv/lib/python3.11/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=105 is greater than n_features=100. All the features will be returned.
#   warnings.warn(
# Running FS-SCB Anova 100 feats:  40%|████      | 2/5 [00:46<01:10, 23.58s/it]/home/martin/Projects/SparseSequentialLearning/.venv/lib/python3.11/site-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=105 is greater than n_features=100. All the features will be returned.
#   warnings.warn(
# ...

# %%
settings_dir = "../../../configurations/paper_figures"
simulator = SettingsSimulator(settings_dir, "FSSCB_different_k_random.json")
simulator.simulate_all("Number of features comparison")
# Out:
# ...
# Running FS-SCB random 100 feats: 100%|██████████| 5/5 [02:59<00:00, 35.99s/it]

# %%
settings_dir = "../../../configurations/paper_figures"
simulator = SettingsSimulator(settings_dir, "FSSCB_different_M_bayesian.json")
simulator.simulate_all("Number of models comparison")
# Out:
# ...
# Running FS-SCB Anova 40 models: 100%|██████████| 5/5 [05:43<00:00, 68.71s/it]

# %%
settings_dir = "../../../configurations/paper_figures"
simulator = SettingsSimulator(settings_dir, "FSSCB_different_M_random.json")
simulator.simulate_all("Number of models comparison")
# Out:
# ...
# Running FS-SCB random 40 models: 100%|██████████| 5/5 [06:40<00:00, 80.02s/it]
