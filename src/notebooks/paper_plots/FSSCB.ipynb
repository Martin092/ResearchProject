# %%
from src.utility.SettingsSimulator import SettingsSimulator
import matplotlib
# %matplotlib inline

# %%
settings_dir = "../../../configurations/paper_figures"

# %%
simulator = SettingsSimulator(settings_dir, "FSSCB_different_k_bayesian.json")
simulator.simulate_all()
# Out:
# Running Bayesian FS-SCB 20 features: 100%|██████████| 5/5 [02:30<00:00, 30.10s/it]
# Running Bayesian FS-SCB 40 features: 100%|██████████| 5/5 [02:38<00:00, 31.74s/it]
# Running Bayesian FS-SCB 60 features: 100%|██████████| 5/5 [02:32<00:00, 30.55s/it]
# Running Bayesian FS-SCB 80 features: 100%|██████████| 5/5 [02:24<00:00, 28.89s/it]
# Running Bayesian FS-SCB 100 features: 100%|██████████| 5/5 [02:30<00:00, 30.16s/it]

# %%
simulator = SettingsSimulator(settings_dir, "FSSCB_different_k_random.json")
simulator.simulate_all()
# Out:
# Running FS-SCB random 20 features: 100%|██████████| 5/5 [02:07<00:00, 25.41s/it]
# Running FS-SCB random 40 features: 100%|██████████| 5/5 [01:51<00:00, 22.25s/it]
# Running FS-SCB random 60 features: 100%|██████████| 5/5 [01:57<00:00, 23.44s/it]
# Running FS-SCB random 80 features: 100%|██████████| 5/5 [01:50<00:00, 22.16s/it]
# Running FS-SCB random 100 features: 100%|██████████| 5/5 [02:00<00:00, 24.17s/it]

# %%
simulator = SettingsSimulator(settings_dir, "FSSCB_different_M_bayesian.json")
simulator.simulate_all()
# Out:
# Running Bayesian FS-SCB 1 model: 100%|██████████| 5/5 [01:12<00:00, 14.57s/it]
# Running Bayesian FS-SCB 5 models: 100%|██████████| 5/5 [01:38<00:00, 19.72s/it]
# Running Bayesian FS-SCB 10 models: 100%|██████████| 5/5 [02:04<00:00, 24.93s/it]
# Running Bayesian FS-SCB 20 models: 100%|██████████| 5/5 [03:20<00:00, 40.16s/it]
# Running Bayesian FS-SCB 40 models: 100%|██████████| 5/5 [05:38<00:00, 67.65s/it]

# %%
simulator = SettingsSimulator(settings_dir, "FSSCB_different_M_random.json")
simulator.simulate_all()
# Out:
# Running FS-SCB random 1 model: 100%|██████████| 5/5 [00:46<00:00,  9.38s/it]
# Running FS-SCB random 5 models: 100%|██████████| 5/5 [01:12<00:00, 14.57s/it]
# Running FS-SCB random 10 models: 100%|██████████| 5/5 [01:54<00:00, 22.82s/it]
# Running FS-SCB random 20 models: 100%|██████████| 5/5 [03:24<00:00, 40.96s/it]
# Running FS-SCB random 40 models: 100%|██████████| 5/5 [05:56<00:00, 71.39s/it]
