# %%
from src.utility.SettingsSimulator import SettingsSimulator
import matplotlib
# %matplotlib inline

# %%
settings_dir = "../../../configurations/paper_figures"

# %%
simulator = SettingsSimulator(settings_dir, "full_comparison_k=40.json")
simulator.simulate_all()
# Out:
# ...
# Running FS-SCB random M=15: 100%|██████████| 5/5 [02:56<00:00, 35.33s/it]

# %%
simulator = SettingsSimulator(settings_dir, "full_comparison_k=80.json")
simulator.simulate_all()
# Out:
# ...
# Running LinUCB k=80: 100%|██████████| 5/5 [00:37<00:00,  7.42s/it]
