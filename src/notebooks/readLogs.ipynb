# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv("/home/martin/Projects/SparseSequentialLearning/results/run_Simulation Example_20250506_135419/log.csv")
# Out:
#               Name  Trial  Round  Context  Action     Reward     Regret  \
# 0         SquareCB      1      1      NaN     NaN  -0.169545  11.544741
# 1         SquareCB      1      2      NaN     NaN  -1.519127  20.434328
# 2         SquareCB      1      3      NaN     NaN  -7.517334  19.229179
# 3         SquareCB      1      4      NaN     NaN  18.898856   0.028198
# 4         SquareCB      1      5      NaN     NaN  29.056772  -0.077080
# ...            ...    ...    ...      ...     ...        ...        ...
# 3995  ETC with N=2     20     96      NaN     NaN   4.013700  20.816014
# 3996  ETC with N=2     20     97      NaN     NaN -13.574012  40.262883
# 3997  ETC with N=2     20     98      NaN     NaN  -0.155067  24.522610
# 3998  ETC with N=2     20     99      NaN     NaN   7.207659  23.618790
# 3999  ETC with N=2     20    100      NaN     NaN   1.448216  23.214548
#
#                      Time
# 0     2025/05/06-13:54:19
# 1     2025/05/06-13:54:19
# ...
